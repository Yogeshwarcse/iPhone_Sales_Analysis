# %%
# ------------------ IMPORT LIBRARIES ------------------
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px

# Display settings
pd.set_option('display.max_columns', None)
print("Libraries Loaded Successfully ✔")


# ------------------ LOAD DATASET ------------------
df = pd.read_csv("apple_products.csv")
print("\nDataset Loaded Successfully ✔")
df.head()
# Out:
# Libraries Loaded Successfully ✔
#
# Dataset Loaded Successfully ✔
#                                Product Name  \
# 0         APPLE iPhone 8 Plus (Gold, 64 GB)
# 1  APPLE iPhone 8 Plus (Space Grey, 256 GB)
# 2      APPLE iPhone 8 Plus (Silver, 256 GB)
# 3           APPLE iPhone 8 (Silver, 256 GB)
# 4             APPLE iPhone 8 (Gold, 256 GB)
#
#                                          Product URL  Brand  Sale Price  \
# 0  https://www.flipkart.com/apple-iphone-8-plus-g...  Apple       49900
# 1  https://www.flipkart.com/apple-iphone-8-plus-s...  Apple       84900
# 2  https://www.flipkart.com/apple-iphone-8-plus-s...  Apple       84900
# 3  https://www.flipkart.com/apple-iphone-8-silver...  Apple       77000
# 4  https://www.flipkart.com/apple-iphone-8-gold-2...  Apple       77000
#
#      Mrp  Discount Percentage  Number Of Ratings  Number Of Reviews  \
# 0  49900                    0               3431                356
# ...

# %%
# ------------------ BASIC INFO ------------------
print("\nDataset Shape:", df.shape)
print("\nMissing Values:\n", df.isnull().sum())
df.info()
# Out:
# Dataset Shape: (62, 11)
#
# Missing Values:
#  Product Name           0
# Product URL            0
# Brand                  0
# Sale Price             0
# Mrp                    0
# Discount Percentage    0
# Number Of Ratings      0
# Number Of Reviews      0
# Upc                    0
# Star Rating            0
# Ram                    0
# dtype: int64
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 62 entries, 0 to 61
# Data columns (total 11 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Product Name         62 non-null     object
#  1   Product URL          62 non-null     object
#  2   Brand                62 non-null     object
#  3   Sale Price           62 non-null     int64
#  4   Mrp                  62 non-null     int64
#  5   Discount Percentage  62 non-null     int64
#  6   Number Of Ratings    62 non-null     int64
#  7   Number Of Reviews    62 non-null     int64
# ...

# %%
# ------------------ DESCRIPTIVE STATISTICS ------------------
df.describe()
# Out:
#           Sale Price            Mrp  Discount Percentage  Number Of Ratings  \
# count      62.000000      62.000000            62.000000          62.000000
# mean    80073.887097   88058.064516             9.951613       22420.403226
# std     34310.446132   34728.825597             7.608079       33768.589550
# min     29999.000000   39900.000000             0.000000         542.000000
# 25%     49900.000000   54900.000000             6.000000         740.000000
# 50%     75900.000000   79900.000000            10.000000        2101.000000
# 75%    117100.000000  120950.000000            14.000000       43470.000000
# max    140900.000000  149900.000000            29.000000       95909.000000
#
#        Number Of Reviews  Star Rating
# count          62.000000    62.000000
# mean         1861.677419     4.575806
# std          2855.883830     0.059190
# min            42.000000     4.500000
# 25%            64.000000     4.500000
# 50%           180.000000     4.600000
# ...

# %%
# ------------------ TOP RATED IPHONES ------------------
top_rated = df.sort_values(by="Star Rating", ascending=False).head(10)

fig = px.bar(top_rated, 
             x="Product Name", 
             y="Star Rating", 
             title="Top 10 Highest Rated iPhones",
             color="Star Rating")

fig.show()

# %%
# ------------------ MOST REVIEWED IPHONES ------------------
most_reviewed = df.sort_values(by="Number Of Reviews", ascending=False).head(10)

fig = px.bar(most_reviewed,
             x="Product Name",
             y="Number Of Reviews",
             title="Top 10 Most Reviewed iPhones",
             color="Number Of Reviews")

fig.show()

# %%
# ------------------ RELATIONSHIP: SALE PRICE vs RATINGS ------------------
fig = px.scatter(df,
                 x="Sale Price",
                 y="Number Of Ratings",
                 size="Star Rating",
                 color="Star Rating",
                 title="Relationship Between Sale Price and Number of Ratings")

fig.show()

# %%
# ------------------ RELATIONSHIP: DISCOUNT vs POPULARITY ------------------
fig = px.scatter(df,
                 x="Discount Percentage",
                 y="Number Of Ratings",
                 color="Star Rating",
                 size="Number Of Reviews",
                 title="Impact of Discount on iPhone Popularity")

fig.show()

# %%
# ------------------ CORRELATION ANALYSIS ------------------
plt.figure(figsize=(8,5))
sns.heatmap(df.corr(numeric_only=True), annot=True, cmap="coolwarm")
plt.title("Correlation Heatmap")
plt.show()

# %%
# ------------------ SUMMARY CONCLUSION ------------------
print("\n📌 Key Insights:")
print("------------------------------------------------")
print("✔ Higher discounts tend to increase number of ratings and reviews.")
print("✔ Sale price has a negative correlation with the number of ratings.")
print("✔ The most popular iPhones are mid-priced models rather than highest-priced.")
print("✔ High star ratings do not always mean high sales—reviews matter more.")
# Out:
# 📌 Key Insights:
# ------------------------------------------------
# ✔ Higher discounts tend to increase number of ratings and reviews.
# ✔ Sale price has a negative correlation with the number of ratings.
# ✔ The most popular iPhones are mid-priced models rather than highest-priced.
# ✔ High star ratings do not always mean high sales—reviews matter more.
